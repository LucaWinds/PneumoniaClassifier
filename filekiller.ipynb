# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil
import os

source_folder = '/content/drive/MyDrive/ColabNotebooks/프로젝트/PneumoniaClassifier/data/train/PNEUMONIA'

len(os.listdir(source_folder))

# %%
file_names = os.listdir(source_folder)[:2500]
file_paths = [os.path.join(source_folder, file_name) for file_name in file_names]

for file_path in file_paths:
    if os.path.isfile(file_path):
        os.remove(file_path)
        print(f"{file_path} deleted successfully")
    else:
        print(f"{file_path} does not exist")
